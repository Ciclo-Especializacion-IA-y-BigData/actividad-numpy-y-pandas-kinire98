# %% [markdown]
# #  Introducción a **Pandas**
#
# ##  ¿Qué es Pandas?
#
# **Pandas** es una **biblioteca de Python** diseñada para trabajar con **conjuntos de datos** (*datasets*).
# Permite **analizar, limpiar, explorar y transformar datos** de forma sencilla, rápida y muy poderosa.
#
# El nombre *Pandas* proviene de **“Panel Data”** y **“Python Data Analysis”**.
# Fue creada por **Wes McKinney** en **2008** y se ha convertido en una herramienta esencial en ciencia de datos y aprendizaje automático.
#
# ---
#
# ## ¿Por qué usar Pandas?
#
# En proyectos de **Inteligencia Artificial** y **Machine Learning**, los datos son la base de todo.
# Sin datos limpios y organizados, ningún modelo funcionará correctamente.
#
# Pandas nos ayuda a:
#
# *  **Limpiar datos desordenados**: eliminar valores nulos, duplicados o inconsistentes.
# *  **Explorar la información**: descubrir patrones, calcular estadísticas o relaciones entre variables.
# *  **Preparar los datos para el aprendizaje automático**: normalizar, dividir o combinar conjuntos de datos.
#
#  En resumen: **Pandas convierte datos en conocimiento**.
#
# ---
#
# ##  Conexión con la Ciencia de Datos
#
# La **Ciencia de Datos** (*Data Science*) es una rama de la informática que estudia **cómo almacenar, usar y analizar datos para obtener información útil**.
#
# Pandas es una de las herramientas fundamentales de esta disciplina, junto con **NumPy**, **Matplotlib** y **Scikit-learn**.
#
# ---
#
# ##  ¿Qué puede hacer Pandas?
#
# Con Pandas puedes responder preguntas importantes sobre tus datos, por ejemplo:
#
# * ¿Existe **correlación** entre dos o más columnas?
# * ¿Cuál es el **valor medio, máximo o mínimo**?
# * ¿Qué filas contienen datos incorrectos o vacíos?
# * ¿Cómo puedo **filtrar, ordenar o combinar** distintas tablas?
#
# Además, Pandas puede **eliminar o sustituir valores vacíos**, tarea conocida como **limpieza de datos** (*data cleaning*).
#
# ---
#
# ##  Dónde encontrar Pandas
#
# El código fuente de Pandas es **abierto y colaborativo**.
# Puedes verlo, estudiar su evolución o incluso contribuir en su repositorio oficial de GitHub:
#
# 🔗 [https://github.com/pandas-dev/pandas](https://github.com/pandas-dev/pandas)
#
# > 💬 *GitHub permite que miles de personas colaboren en el mismo proyecto de software, mejorándolo entre todos.*
#
# ---
#
# ## Resumen
#
# | Concepto                | Descripción                                                  |
# | ----------------------- | ------------------------------------------------------------ |
# | **Pandas**              | Librería de Python para el análisis y manipulación de datos. |
# | **Funcionalidades**     | Limpieza, exploración, análisis y combinación de datos.      |
# | **Creador**             | Wes McKinney (2008).                                         |
# | **Usos principales**    | Ciencia de datos, análisis estadístico, Machine Learning.    |
# | **Repositorio oficial** | [pandas-dev/pandas](https://github.com/pandas-dev/pandas)    |
#
# ---

# %% [markdown]
# #  **Primeros pasos con Pandas**
#
# ##  Instalación de Pandas
#
# Para poder usar Pandas, primero debemos **instalarlo en nuestro entorno de Python**.
# Si ya tienes **Python** y **PIP** (el gestor de paquetes de Python) instalados en tu equipo, la instalación es muy sencilla.
#
# Ejecuta en la terminal el siguiente comando:

# %%
pip install pandas
# Out:
# error: externally-managed-environment
#
# × This environment is externally managed
# ╰─> To install Python packages system-wide, try 'pacman -S
#     python-xyz', where xyz is the package you are trying to
#     install.
#
#     If you wish to install a non-Arch-packaged Python package,
#     create a virtual environment using 'python -m venv path/to/venv'.
#     Then use path/to/venv/bin/python and path/to/venv/bin/pip.
#
#     If you wish to install a non-Arch packaged Python application,
#     it may be easiest to use 'pipx install xyz', which will manage a
#     virtual environment for you. Make sure you have python-pipx
#     installed via pacman.
#
# note: If you believe this is a mistake, please contact your Python installation or OS distribution provider. You can override this, at the risk of breaking your Python installation or OS, by passing --break-system-packages.
# hint: See PEP 668 for the detailed specification.
# ...

# %% [markdown]
#  Este comando descarga e instala Pandas junto con sus dependencias (como **NumPy**, que Pandas usa internamente).
#
# >  Consejo: En algunos equipos, especialmente con varios entornos de Python, puede ser necesario usar:
# >
# > ```bash
# > python -m pip install pandas
# > ```
#
# Si tienes problemas con la instalación o no quieres complicarte con dependencias, puedes usar una **distribución de Python científica** que ya incluye Pandas, como:
#
# *  **Anaconda** (la más recomendada para IA y ciencia de datos).
# *  **Spyder** (entorno de desarrollo con consola integrada).
# *  **Google Colab** (ya lo trae preinstalado, accesible desde el navegador).
#
# ---
#
# ##  Importar Pandas
#
# Una vez instalado, debes **importar la librería** en tu programa Python usando la palabra clave `import`:

# %%
import pandas

# %% [markdown]
# A partir de ese momento, todas las funciones de Pandas estarán disponibles en tu script.
#
#  📘 **Ejemplo básico:**

# %%
import pandas

mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pandas.DataFrame(mydataset)

print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %% [markdown]
#  **Qué ocurre aquí:**
#
# * Creamos un **diccionario** llamado `mydataset` con dos listas: una de coches y otra de números.
# * Convertimos ese diccionario en un **DataFrame**, que es la estructura de datos principal de Pandas (parecida a una hoja de cálculo o tabla SQL).
# * Finalmente, imprimimos el DataFrame.
#
# La salida será:
#
# ```
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2
# ```
#
# ---
#
# ##  Usar Pandas con un alias (`pd`)
#
# En la práctica, casi todos los programadores importan Pandas con un **alias**, es decir, un nombre corto y fácil de escribir: `pd`.
#
# Un **alias** en Python es un nombre alternativo para referirse a algo.
# Se crea usando la palabra clave `as`.

# %%
import pandas as pd

# %% [markdown]
# A partir de ese momento, puedes usar `pd` en lugar de escribir `pandas` completo.
#
#  📘 **Ejemplo:**

# %%
import pandas as pd

mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pd.DataFrame(mydataset)

print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %% [markdown]
# La salida será exactamente la misma, pero el código se ve más limpio y profesional.
#
# >  En todos los ejemplos del curso usaremos siempre el alias `pd`, porque es el estándar en ciencia de datos y aprendizaje automático.
#
# ---
#
# ##  Ver la versión de Pandas instalada
#
# Para comprobar qué versión de Pandas tienes instalada, puedes acceder al atributo `__version__`:

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.3.1

# %% [markdown]
# Esto mostrará algo parecido a:
#
# ```
# 2.2.3
# ```
#
# > 🔍 Es importante conocer la versión, porque algunas funciones pueden cambiar o desaparecer entre versiones.
# > En el entorno profesional (y en IA), siempre se recomienda **especificar la versión exacta en los archivos de proyecto** (`requirements.txt`, `environment.yml`, etc.).
#
# ---
#
# ##  Resumen visual
#
# | Concepto                       | Descripción                             |
# | ------------------------------ | --------------------------------------- |
# | **Instalación**                | `pip install pandas`                    |
# | **Importación estándar**       | `import pandas`                         |
# | **Importación con alias**      | `import pandas as pd`                   |
# | **Estructura básica de datos** | `DataFrame`                             |
# | **Ver versión instalada**      | `pd.__version__`                        |
# | **Entornos recomendados**      | Anaconda, Spyder, Jupyter, Google Colab |
#
# ---

# %% [markdown]
# #  **Pandas Series**
#
# ##  ¿Qué es una *Series*?
#
# Una **Series** de Pandas es como una **columna de una tabla** o de una hoja de cálculo.
# Es una **estructura unidimensional** (una sola dimensión) que puede almacenar **datos de cualquier tipo**: números, cadenas, valores booleanos, etc.
#
# Puedes imaginarla como una lista con nombre o una columna de Excel con índices.
#
# ---
#
# ##  Crear una *Series* desde una lista
#
# 📘 **Ejemplo:**

# %%
import pandas as pd

a = [1, 7, 2]

myvar = pd.Series(a)

print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %% [markdown]
# Cada valor tiene una **etiqueta o índice** (label).
# Por defecto, Pandas asigna índices numéricos empezando desde 0.
#
# ---
#
# ##  **Índices o etiquetas (Labels)**
#
# Si no especificas nada, los elementos se etiquetan automáticamente como:
#
# ```
# 0, 1, 2, 3, ...
# ```
#
# Estos índices te permiten **acceder a un valor concreto**.
#
# 📘 **Ejemplo: acceder al primer valor**

# %%
print(myvar[0])
# Out:
# 1

# %% [markdown]
# ---
#
# ##  **Crear tus propias etiquetas**
#
# Puedes asignar tus **propias etiquetas** (índices personalizados) con el argumento `index`.
#
# 📘 **Ejemplo:**

# %%
import pandas as pd

a = [1, 7, 2]

myvar = pd.Series(a, index = ["x", "y", "z"])

print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %% [markdown]
# Y ahora puedes acceder por etiqueta en lugar de por posición:

# %%
print(myvar["y"])
# Out:
# 7

# %% [markdown]
# Otra forma muy útil de crear una Series es a partir de un **diccionario de Python**.
# Las **claves** del diccionario se convierten automáticamente en los **índices**.
#
# 📘 **Ejemplo:**

# %%
import pandas as pd

calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)

print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %% [markdown]
# ##  **Seleccionar elementos concretos**
#
# Puedes elegir **solo algunas claves del diccionario** indicando los nombres que quieres conservar en el argumento `index`.
#
# 📘 **Ejemplo:**

# %%
import pandas as pd

calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories, index = ["day1", "day2"])

print(myvar)
# Out:
# day1    420
# day2    380
# dtype: int64

# %% [markdown]
#  **De Series a DataFrame**
#
# En Pandas, los conjuntos de datos suelen tener **varias columnas** (no solo una).
# Cuando combinamos varias *Series* con distintos nombres de columna, obtenemos un **DataFrame**, que es una **tabla completa de datos**.
#
# 📘 **Ejemplo:**

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

myvar = pd.DataFrame(data)

print(myvar)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %% [markdown]
# En este ejemplo, **cada columna es una Series**, y el **DataFrame** las une en una sola estructura.
#
# ---
#
# ##  Resumen visual
#
# | Concepto                   | Descripción                                              |
# | -------------------------- | -------------------------------------------------------- |
# | **Series**                 | Columna unidimensional en Pandas.                        |
# | **Fuente de datos**        | Puede venir de listas, tuplas o diccionarios.            |
# | **Índices (Labels)**       | Identificadores únicos de cada valor.                    |
# | **Acceso a datos**         | Por posición (`myvar[0]`) o por etiqueta (`myvar["x"]`). |
# | **Relación con DataFrame** | Un DataFrame está formado por varias Series.             |
#
# ---
#
# ##  **Actividad práctica: “Tu primera Series inteligente”**
#
#  **Objetivo:** crear, explorar y acceder a datos de una *Series* de Pandas relacionada con IA.
#
# ### Paso 1: Crear una *Series* de modelos de IA
#
# Crea una *Series* con los nombres de tres modelos de IA y su precisión (accuracy): Ej. Regresión Lineal 0.82

# %%
import pandas as pd

modelos = pd.Series({
    "regresion": 0.83,
    "arbol": 0.21,
    "Red Neuronal": 0.45
})
print(modelos)
# Out:
# regresion       0.83
# arbol           0.21
# Red Neuronal    0.45
# dtype: float64

# %% [markdown]
# ### Paso 2: Acceder a un valor específico
#
# Muestra la precisión del modelo **"Red Neuronal"** usando su etiqueta.
#
#
#
#
#
#
# ---

# %%
import pandas as pd

modelos = pd.Series({
    "regresion": 0.83,
    "arbol": 0.21,
    "Red Neuronal": 0.45
})

print(modelos["Red Neuronal"])
# Out:
# 0.45

# %% [markdown]
# ### Paso 3: Filtrar solo los modelos con precisión superior a 0.85
#
# *(Pista: usa comparación booleana)*

# %%
import pandas as pd

modelos = pd.Series({
    "regresion": 0.89,
    "arbol": 0.21,
    "Red Neuronal": 0.45
})

print(modelos[modelos > 0.85])
# Out:
# regresion    0.89
# dtype: float64

# %% [markdown]
#  **Reflexión final**
#
# * ¿Qué ventajas tiene usar *Series* frente a listas normales de Python?
# * ¿Por qué crees que Pandas usa etiquetas (index) en lugar de posiciones numéricas fijas?
#
# ---
#
# **Próxima sección:** *Pandas DataFrames – La estructura principal para el análisis de datos en IA.*
# ¿Quieres que en esa incluyamos también una **actividad práctica más aplicada**, como cargar un dataset real en un DataFrame (por ejemplo, un CSV con datos de coches o viviendas)?

# %% [markdown]
# #  Introducción a los DataFrames en Pandas
#
# ## ¿Qué es un DataFrame?
#
# Un **DataFrame** de **Pandas** es una estructura de datos **bidimensional** (2D), similar a una **tabla** con filas y columnas.
# Piensa en él como una hoja de cálculo de Excel, pero **dentro de Python**, con superpoderes para análisis de datos.
#
# 🔹 Cada columna puede tener un tipo distinto (números, texto, booleanos…).
#
# 🔹 Cada fila tiene un **índice** (por defecto empieza en 0).
#
# 🔹 Es la base del **análisis de datos** y de la **preparación de datasets** en IA.
#
# ---
#
# ##  Crear un DataFrame

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

# Cargar los datos en un objeto DataFrame
df = pd.DataFrame(data)

print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %% [markdown]
# Observa:
#
# * Cada clave del diccionario (`"calories"`, `"duration"`) se convierte en una **columna**.
# * Cada elemento de la lista es un **valor** de fila.
#
# ---
#
# ## Localizar filas con `loc`
#
# Puedes acceder a filas específicas usando el **índice** o el **nombre de la fila** (si lo has definido).
#
# ### Ejemplo 1: Obtener la primera fila

# %%
print(df.loc[0])
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64

# %% [markdown]
# **Devuelve una Series**, no un DataFrame, porque solo hay una fila.
#
# ---
#
# 📘 **Ejemplo 2: devolver varias filas**

# %%
print(df.loc[[0, 1]])
# Out:
#    calories  duration
# 0       420        50
# 1       380        40

# %% [markdown]
# En este caso, al usar una **lista de índices**, Pandas devuelve otro **DataFrame**.
#
# ---
#
# ## 🏷️ **Índices con nombre (Named Indexes)**
#
# Puedes asignar **nombres personalizados** a las filas mediante el argumento `index`.
#
# 📘 **Ejemplo:**

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index=["day1", "day2", "day3"])

print(df)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %% [markdown]
# Ahora las filas tienen **etiquetas significativas** en lugar de números.
#
# ---
#
# ## 📍 **Acceder a una fila por nombre**
#
# Una vez asignados nombres, puedes usar `.loc[]` con esos nombres.
#
# 📘 **Ejemplo:**

# %%
print(df.loc["day2"])
# Out:
# calories    380
# duration     40
# Name: day2, dtype: int64

# %% [markdown]
# ---
#
# ##  **Cargar datos desde un archivo**
#
# En proyectos reales de *Machine Learning*, los datos no se escriben a mano, sino que se **cargan desde archivos**: CSV, Excel, JSON, SQL, etc.
#
# Pandas facilita esto con funciones como `read_csv()` o `read_excel()`.
#
# 📘 **Ejemplo:**
#
# Vamos a usar el dataset real de empleados disponible en GitHub:
# 📂 [`employees.csv`](https://raw.githubusercontent.com/sivabalanb/Data-Analysis-with-Pandas-and-Python/refs/heads/master/employees.csv)

# %%
import pandas as pd

# Cargar el dataset desde la URL
url = "https://raw.githubusercontent.com/sivabalanb/Data-Analysis-with-Pandas-and-Python/refs/heads/master/employees.csv"
df = pd.read_csv(url)

# Mostrar las primeras filas
print(df.head())
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %% [markdown]
# Por defecto, Pandas interpreta los datos separados por comas (`,`).
# > Si tu archivo usa otro separador, puedes indicarlo con el parámetro `sep`, por ejemplo:
# >
# > ```python
# > df = pd.read_csv('data.csv', sep=';')
# > ```
#
# ---

# %% [markdown]
# ## **Explorar el DataFrame**
#
# Podemos usar varios métodos para **inspeccionar la estructura** de los datos.

# %%
print(df.info())      # información general
print(df.describe())  # estadísticas básicas de las columnas numéricas
print(df.columns)     # nombres de las columnas
print(df.shape)       # dimensiones (filas, columnas)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB
# None
#               Salary      Bonus %
# count    1000.000000  1000.000000
# mean    90662.181000    10.207555
# std     32923.693342     5.528481
# min     35013.000000     1.015000
# 25%     62613.000000     5.401750
# 50%     90428.000000     9.838500
# 75%    118740.250000    14.838000
# max    149908.000000    19.944000
# ...

# %% [markdown]
# ---
#
# ## **Filtrar información**
#
# Los DataFrames permiten **aplicar condiciones lógicas** para seleccionar subconjuntos de datos.
#
# 📘 **Ejemplo: empleados con sueldo mayor de 60.000**

# %%
altos_salarios = df[df["salary"] > 60000]
print(altos_salarios)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'salary'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 altos_salarios = df[df["salary"] > 60000]
# ...

# %% [markdown]
# 📘 **Ejemplo: empleados del departamento de IT**

# %%
it = df[df["department"] == "IT"]
print(it)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'department'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 it = df[df["department"] == "IT"]
# ...

# %% [markdown]
# ##  Resumen
#
# | Concepto                   | Descripción                                                 |
# | -------------------------- | ----------------------------------------------------------- |
# | **DataFrame**              | Estructura bidimensional (tabla con filas y columnas).      |
# | **Creación**               | A partir de diccionarios, listas, o archivos (CSV, Excel…). |
# | **Acceso a filas**         | `.loc[]` por índice o etiqueta.                             |
# | **Índices personalizados** | Se definen con el argumento `index`.                        |
# | **Archivos externos**      | `pd.read_csv()`, `pd.read_excel()`, etc.                    |
# | **Relación con Series**    | Cada columna del DataFrame es una Series.                   |
#
# ---

# %% [markdown]
# Actividad práctica: **Análisis de Pokémon con Pandas**
#
# 🎯 **Objetivo:** Aplicar lo aprendido para explorar un dataset real.
#
# 📂 Dataset:
# [`Pokemon.csv`](https://raw.githubusercontent.com/MainakRepositor/Datasets/refs/heads/master/Pokemon.csv)
#
# ---
#
# ## 🔹 Paso 1. Cargar el dataset

# %%
import pandas as pd

pukimones = pd.read_csv("https://raw.githubusercontent.com/MainakRepositor/Datasets/refs/heads/master/Pokemon.csv")

print(pukimones)
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# Observa cuántas filas y columnas tiene:

# %%
print(len(pukimones.columns)) # columnas
print(len(pukimones)) # filas
# Out:
# 13
# 800

# %% [markdown]
# ## 🔹 Paso 2. Explorar la estructura
#
# Mira los nombres de las columnas:

# %%
print(pukimones.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# Ejemplo de salida:
#
# ```
# Index(['Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense', ...])
# ```
#
# ---
#
# ## 🔹 Paso 3. Seleccionar filas y columnas
#
# Selecciona:
#
#
# * El primer pokemon
# * Los tres primeros Pokémon
# * Mostrar solo los nombres y ataques

# %%
print(pukimones.iloc[0])
print(pukimones.iloc[:3])
print(pukimones[["Name", "Attack"]])
# Out:
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# Total               318
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: Bulbasaur, dtype: object
#            #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur  1  Bulbasaur  Grass  Poison    318  45      49       49       65
# Ivysaur    2    Ivysaur  Grass  Poison    405  60      62       63       80
# Venusaur   3   Venusaur  Grass  Poison    525  80      82       83      100
#
#            Sp. Def  Speed  Generation  Legendary
# Name
# Bulbasaur       65     45           1      False
# Ivysaur         80     60           1      False
# Venusaur       100     80           1      False
#                                         Name  Attack
# Name
# ...

# %% [markdown]
# ---
#
# ## 🔹 Paso 4. Cambiar el índice
#
# Queremos que el nombre del Pokémon sea el índice:

# %%
pukimones.set_index("Name", inplace=True, drop=False)
print(pukimones.loc["Bulbasaur"])
# Out:
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# Total               318
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: Bulbasaur, dtype: object

# %% [markdown]
# ## 🔹 Paso 5. Reto
#
# Calcula el promedio de “Attack” por tipo de Pokémon (`Type 1`):

# %%
print(pukimones.groupby("Type 1")["Attack"].mean())
# Out:
# Type 1
# Bug          70.971014
# Dark         88.387097
# Dragon      112.125000
# Electric     69.090909
# Fairy        61.529412
# Fighting     96.777778
# Fire         84.769231
# Flying       78.750000
# Ghost        73.781250
# Grass        73.214286
# Ground       95.750000
# Ice          72.750000
# Normal       73.469388
# Poison       74.678571
# Psychic      71.456140
# Rock         92.863636
# Steel        92.703704
# Water        74.151786
# Name: Attack, dtype: float64

# %% [markdown]
# ¿Qué tipo tiene el ataque medio más alto?

# %% [markdown]
# ---
#
# En proyectos de *Machine Learning*, estos pasos son esenciales:
#
# 1. Cargar y limpiar datos.
# 2. Seleccionar variables relevantes.
# 3. Analizar relaciones antes de entrenar modelos.
#
# Próximamente aprenderás a **preparar** estos DataFrames para su uso en algoritmos de IA (normalización, codificación, entrenamiento y test)

# %% [markdown]
# #  Lección: Leer archivos CSV con Pandas
#
# ##  ¿Qué es un archivo CSV?
#
# Los archivos **CSV** (*Comma Separated Values*) son una forma **sencilla y universal** de guardar grandes conjuntos de datos.
# Cada línea representa una **fila**, y las columnas están separadas por **comas (,)**.
#
# 🔹 Son archivos de texto plano.
# 🔹 Se pueden abrir con Excel, Google Sheets o cualquier editor de texto.
# 🔹 Se usan constantemente en proyectos de **Big Data** y **Machine Learning**.
#
# ---
#
# ##  Cargar un archivo CSV con Pandas
#
# Pandas facilita enormemente leer un archivo CSV.
# Vamos a cargar un dataset llamado `data.csv`.

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/MainakRepositor/Datasets/refs/heads/master/Breast%20Cancer%20Dataset.csv"

df = pd.read_csv(url)

print(df.to_string())
# Out:
#             id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  compactness_mean  concavity_mean  concave points_mean  symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se  area_se  smoothness_se  compactness_se  concavity_se  concave points_se  symmetry_se  fractal_dimension_se  radius_worst  texture_worst  perimeter_worst  area_worst  smoothness_worst  compactness_worst  concavity_worst  concave points_worst  symmetry_worst  fractal_dimension_worst  Unnamed: 32
# ...

# %% [markdown]
#  `to_string()` muestra **todo el DataFrame completo** (aunque sea grande).
#
# ---
#
# ###  Sin `to_string()`
#
# Si no usamos `to_string()`, Pandas mostrará **solo las primeras y últimas 5 filas**, para no saturar la pantalla:

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/MainakRepositor/Datasets/refs/heads/master/Breast%20Cancer%20Dataset.csv"

df = pd.read_csv(url)

print(df)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %% [markdown]
# ---
#
# ## ⚙️ Controlar cuántas filas se muestran
#
# Pandas tiene una configuración interna llamada `pd.options.display.max_rows`, que define el número máximo de filas que se muestran por defecto.
#
# ---
#
# ### 🔍 Ver cuántas filas máximas se muestran

# %%
import pandas as pd

print(pd.options.display.max_rows)
# Out:
# 60

# %% [markdown]
# ➡️ Esto significa que, si tu DataFrame tiene más de 60 filas, solo se mostrarán **las primeras y las últimas 5**.
#
# ---
#
# ### 🔧 Cambiar el límite de filas visibles
#
# Si quieres mostrar **todas** las filas de un DataFrame, puedes aumentar este límite:

# %%
import pandas as pd

pd.options.display.max_rows = 9999   # Aumentamos el máximo

url = "https://raw.githubusercontent.com/MainakRepositor/Datasets/refs/heads/master/Breast%20Cancer%20Dataset.csv"

df = pd.read_csv(url)

print(df)
# Out:
#             id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0       842302         M       17.990         10.38          122.80
# 1       842517         M       20.570         17.77          132.90
# 2     84300903         M       19.690         21.25          130.00
# 3     84348301         M       11.420         20.38           77.58
# 4     84358402         M       20.290         14.34          135.10
# 5       843786         M       12.450         15.70           82.57
# 6       844359         M       18.250         19.98          119.60
# 7     84458202         M       13.710         20.83           90.20
# 8       844981         M       13.000         21.82           87.50
# 9     84501001         M       12.460         24.04           83.97
# 10      845636         M       16.020         23.24          102.70
# 11    84610002         M       15.780         17.89          103.60
# 12      846226         M       19.170         24.80          132.40
# ...

# %% [markdown]
# ⚠️ **Cuidado:** Si tu archivo tiene miles de filas, puede tardar en mostrarse todo.
#
# ---
#
# ## En resumen
#
# | Comando                       | Descripción                                          |
# | ----------------------------- | ---------------------------------------------------- |
# | `pd.read_csv('archivo.csv')`  | Carga un archivo CSV como DataFrame                  |
# | `df.to_string()`              | Muestra todo el contenido del DataFrame              |
# | `pd.options.display.max_rows` | Consulta o cambia el número máximo de filas visibles |
#
# ---

# %% [markdown]
# #  **Actividad práctica: Analizando la felicidad mundial con Pandas**
#
#  **Objetivo de aprendizaje:**
# Aplicar las funciones de Pandas para **leer, explorar y analizar datos reales desde un archivo CSV remoto**, interpretando resultados de forma crítica y visual.
#
# ---
#
# ##  **Dataset**
#
#  URL:
# [`https://raw.githubusercontent.com/MainakRepositor/Datasets/refs/heads/master/World%20Happiness%20Data/2020.csv`](https://raw.githubusercontent.com/MainakRepositor/Datasets/refs/heads/master/World%20Happiness%20Data/2020.csv)
#
#  Este dataset contiene datos del **Informe Mundial de la Felicidad 2020**, con información sobre:
#
# * PIB per cápita (economía)
# * Apoyo social
# * Esperanza de vida saludable
# * Libertad para tomar decisiones
# * Generosidad
# * Percepción de corrupción
# * Puntuación de felicidad (0–10)
#
# ---
#
# ## 🪜 **Pasos guiados**
#
# ### 🔹 Paso 1. Cargar el CSV desde Internet

# %%
csv = pd.read_csv("https://raw.githubusercontent.com/MainakRepositor/Datasets/refs/heads/master/World%20Happiness%20Data/2020.csv")

# %% [markdown]
# *¿Cuántas filas y columnas tiene el DataFrame?*

# %%
print("Filas: ", csv.shape[0])
print("Columnas: ", csv.shape[1])
# Out:
# Filas:  153
# Columnas:  20

# %% [markdown]
# ---
#
# ### 🔹 Paso 2. Examinar las columnas y tipos de datos

# %%
print(csv)
# Out:
#                  Country name  Regional indicator  Ladder score  \
# 0                     Finland      Western Europe        7.8087
# 1                     Denmark      Western Europe        7.6456
# 2                 Switzerland      Western Europe        7.5599
# 3                     Iceland      Western Europe        7.5045
# 4                      Norway      Western Europe        7.4880
# ..                        ...                 ...           ...
# 148  Central African Republic  Sub-Saharan Africa        3.4759
# 149                    Rwanda  Sub-Saharan Africa        3.3123
# 150                  Zimbabwe  Sub-Saharan Africa        3.2992
# 151               South Sudan  Sub-Saharan Africa        2.8166
# 152               Afghanistan          South Asia        2.5669
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                          0.031156      7.869766      7.747634
# 1                          0.033492      7.711245      7.579955
# ...

# %% [markdown]
# *Identifica cuáles son variables numéricas (para calcular medias) y cuáles son categóricas (como el país o la región).*

# %%
print(csv.groupby("Regional indicator").mean(numeric_only=True))
# Out:
#                                     Ladder score  \
# Regional indicator
# Central and Eastern Europe              5.883818
# Commonwealth of Independent States      5.358342
# East Asia                               5.714850
# Latin America and Caribbean             5.981786
# Middle East and North Africa            5.227159
# North America and ANZ                   7.173525
# South Asia                              4.475443
# Southeast Asia                          5.383367
# Sub-Saharan Africa                      4.383495
# Western Europe                          6.899219
#
#                                     Standard error of ladder score  \
# Regional indicator
# Central and Eastern Europe                                0.043896
# Commonwealth of Independent States                        0.042306
# East Asia                                                 0.039475
# Latin America and Caribbean                               0.063247
# ...

# %% [markdown]
# ---
#
# ### 🔹 Paso 3. Mostrar una parte del dataset

# %%
print(csv.iloc[-10:])
# Out:
#                  Country name            Regional indicator  Ladder score  \
# 143                     India                    South Asia        3.5733
# 144                    Malawi            Sub-Saharan Africa        3.5380
# 145                     Yemen  Middle East and North Africa        3.5274
# 146                  Botswana            Sub-Saharan Africa        3.4789
# 147                  Tanzania            Sub-Saharan Africa        3.4762
# 148  Central African Republic            Sub-Saharan Africa        3.4759
# 149                    Rwanda            Sub-Saharan Africa        3.3123
# 150                  Zimbabwe            Sub-Saharan Africa        3.2992
# 151               South Sudan            Sub-Saharan Africa        2.8166
# 152               Afghanistan                    South Asia        2.5669
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 143                        0.027702      3.627596      3.519003
# ...

# %% [markdown]
# Muestra las 10 primeras filas.
# ¿Aparece algún valor ausente (`NaN`)? Si es así, prueba:

# %%
print(csv[(csv != 0).all(axis=1)].groupby("Regional indicator").mean(numeric_only=True))
# Out:
#                                     Ladder score  \
# Regional indicator
# Central and Eastern Europe              5.932713
# Commonwealth of Independent States      5.358342
# East Asia                               5.714850
# Latin America and Caribbean             5.981786
# Middle East and North Africa            5.227159
# North America and ANZ                   7.173525
# South Asia                              4.793533
# Southeast Asia                          5.383367
# Sub-Saharan Africa                      4.424462
# Western Europe                          6.968430
#
#                                     Standard error of ladder score  \
# Regional indicator
# Central and Eastern Europe                                0.043876
# Commonwealth of Independent States                        0.042306
# East Asia                                                 0.039475
# Latin America and Caribbean                               0.063247
# ...

# %% [markdown]
# ---
#
# ### 🔹 Paso 4. Ajustar el número de filas visibles
#
# Si el dataset es grande y no se muestra completo, cambia la opción de Pandas para que como máximo muestre 100 filas

# %% [markdown]
# ### 🔹 Paso 5. Analizar la felicidad media por región
#
# (Comprueba si existe una columna como `"Regional indicator"` o `"Region"`)

# %% [markdown]
# *¿Qué región del mundo tiene la mayor puntuación media de felicidad?*
#
# *¿Y cuál la menor?*
#
# *¿Parece que la felicidad aumenta con el PIB o la esperanza de vida?*

# %%
avg_happiness = csv.groupby("Regional indicator")["Ladder score"].mean().sort_values(ascending=False)
print(avg_happiness)
print("Region mas feliz (",avg_happiness.idxmax() ,"): ", avg_happiness.max())
print("Region menos feliz (",avg_happiness.idxmin() ,"): ", avg_happiness.min())

avg_pib = csv.groupby("Regional indicator")["Logged GDP per capita"].mean().sort_values(ascending=False)
print(avg_pib)
print("Region con mas pib per capita (",avg_pib.idxmax() ,"): ", avg_pib.max())
print("Region con menos pib per capita (",avg_pib.idxmin() ,"): ", avg_pib.min())

# Si parece que tienen relacion el maximo y el minimo de felicidad coinciden con las regiones con mas y menos pib respectivamente, los segundos respectivamente tambien. Es en el medio donde parece que hay mas discrepancias
# Out:
# Regional indicator
# North America and ANZ                 7.173525
# Western Europe                        6.899219
# Latin America and Caribbean           5.981786
# Central and Eastern Europe            5.883818
# East Asia                             5.714850
# Southeast Asia                        5.383367
# Commonwealth of Independent States    5.358342
# Middle East and North Africa          5.227159
# South Asia                            4.475443
# Sub-Saharan Africa                    4.383495
# Name: Ladder score, dtype: float64
# Region mas feliz ( North America and ANZ ):  7.17352497575
# Region menos feliz ( Sub-Saharan Africa ):  4.383494866205128
# Regional indicator
# North America and ANZ                 10.709919
# Western Europe                        10.688402
# East Asia                             10.316895
# Central and Eastern Europe             9.975703
# Middle East and North Africa           9.713648
# Southeast Asia                         9.366847
# ...

# %% [markdown]
# ### 🔹 Paso 7. (Opcional) Crea un gráfico para visualizarlo

# %%
import matplotlib.pyplot as plt
import numpy as np

x = csv["Social support"]
y = csv["Ladder score"]

mask = ~x.isna() & ~y.isna()
x = x[mask]
y = y[mask]

plt.scatter(x, y, color="skyblue", label="countries")
slope, intercept = np.polyfit(x, y, 1)
regression_line = slope * x + intercept

residuals = y - regression_line

std_dev = residuals.std()

plt.plot(x, regression_line, color="red", label=f"y = {slope:.2f}x - {intercept:.2f}")
plt.fill_between(
    x,
    regression_line - std_dev,
    regression_line + std_dev,
    color="red",
    alpha=0.2,
    label=f"±{std_dev:.2f} Standard Deviation"
)

plt.xlabel("Social support")
plt.ylabel("Ladder score")

plt.title("Happiness vs Social support")

plt.legend()

plt.show()

# %%
x = csv["Logged GDP per capita"]
y = csv["Ladder score"]

mask = ~x.isna() & ~y.isna()
x = x[mask]
y = y[mask]

plt.scatter(x, y, color="skyblue", label="countries")
slope, intercept = np.polyfit(x, y, 1)
regression_line = slope * x + intercept

residuals = y - regression_line

std_dev = residuals.std()

plt.plot(x, regression_line, color="red", label=f"y = {slope:.2f}x - {intercept:.2f}")
plt.fill_between(
    x,
    regression_line - std_dev,
    regression_line + std_dev,
    color="red",
    alpha=0.2,
    label=f"±{std_dev:.2f} Standard Deviation"
)

plt.xlabel("Logged GDP per capita")
plt.ylabel("Ladder score")

plt.title("Happiness vs GDP per capita")

plt.legend()

plt.show()

# %%
x = csv["Freedom to make life choices"]
y = csv["Ladder score"]

mask = ~x.isna() & ~y.isna()
x = x[mask]
y = y[mask]

plt.scatter(x, y, color="skyblue", label="countries")
slope, intercept = np.polyfit(x, y, 1)
regression_line = slope * x + intercept

residuals = y - regression_line

std_dev = residuals.std()

plt.plot(x, regression_line, color="red", label=f"y = {slope:.2f}x - {intercept:.2f}")
plt.fill_between(
    x,
    regression_line - std_dev,
    regression_line + std_dev,
    color="red",
    alpha=0.2,
    label=f"±{std_dev:.2f} Standard Deviation"
)

plt.xlabel("Freedom to make choices")
plt.ylabel("Ladder score")

plt.title("Happiness vs Freedom to make choices")

plt.legend()

plt.show()

# %% [markdown]
# #  Lección: Leer archivos JSON con Pandas
#
# ##  ¿Qué es un archivo JSON?
#
# JSON (*JavaScript Object Notation*) es un **formato de texto estructurado** que se utiliza para **intercambiar datos entre aplicaciones**, especialmente en la web y en proyectos de Big Data o Inteligencia Artificial.
#
# 🔹 Es el formato más común para las **API** (servicios de datos).
# 🔹 Está formado por **pares clave:valor**, como los diccionarios de Python.
# 🔹 Es legible tanto por humanos como por máquinas.
#
# 📘 Ejemplo de archivo JSON:
#
# ```json
# {
#   "Name": "Carlos",
#   "Age": 28,
#   "City": "León"
# }
# ```
#
# ---
#
# ## 📂 Cargar un JSON en un DataFrame
#
# Podemos usar `read_json()` para leer directamente un archivo JSON y convertirlo en una tabla de Pandas.
#
# En la página https://github.com/jdorfman/awesome-json-datasets podemos encontrar muchos ejemplos para usar.

# %%
import pandas as pd

url_json = "https://raw.githubusercontent.com/Biuni/PokemonGO-Pokedex/master/pokedex.json"

df = pd.read_json(url_json)

print(df.to_string())
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              pokemon
# ...

# %% [markdown]
#  **Consejo:** Usa `.to_string()` para imprimir todo el contenido del DataFrame (por defecto, Pandas oculta algunas filas).
#
# ---
#
# ##  JSON y diccionarios en Python
#
# Los **objetos JSON** tienen **exactamente el mismo formato** que los **diccionarios de Python**.
# Esto significa que puedes crear un DataFrame directamente desde un diccionario.
#
# ---
#
# ### 📘 Ejemplo práctico

# %%
import pandas as pd

data = {
  "Duration": {
    "0": 60, "1": 60, "2": 60, "3": 45, "4": 45, "5": 60
  },
  "Pulse": {
    "0": 110, "1": 117, "2": 103, "3": 109, "4": 117, "5": 102
  },
  "Maxpulse": {
    "0": 130, "1": 145, "2": 135, "3": 175, "4": 148, "5": 127
  },
  "Calories": {
    "0": 409, "1": 479, "2": 340, "3": 282, "4": 406, "5": 300
  }
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %% [markdown]
# ## 🔍¿Por qué es importante JSON en IA?
#
# En proyectos de Inteligencia Artificial:
#
# * Los **datasets online** (por ejemplo, de APIs o webs) suelen venir en formato JSON.
# * Permite **automatizar** la carga de datos sin necesidad de descargarlos manualmente.
# * Es ideal para trabajar con **información jerárquica** (usuarios, productos, sensores…).
#
# ---
#
# ## 💡 Ejemplo de uso real
#
# Existen muchas APIS gratuitas de las que podemos obtener datos, algunas requieren registro previo para tener un api key:
#
# https://free-apis.github.io/
#
# Supón que tienes una API que devuelve datos meteorológicos en formato JSON.
# Con Pandas puedes cargar esos datos directamente y analizarlos.

# %%
import requests
import pandas as pd

# 1. Definir los parámetros para la API
# Coordenadas de León, España
latitud = 42.60
longitud = -5.57

# Rango de fechas para los datos históricos (ej. todo el año 2023)
fecha_inicio = "2023-01-01"
fecha_fin = "2023-12-31"

# Variables diarias que queremos obtener:
# - temperature_2m_max: Temperatura máxima diaria a 2 metros del suelo.
# - temperature_2m_min: Temperatura mínima diaria.
# - precipitation_sum: Suma total de precipitación (lluvia, nieve...) en mm.
# - wind_speed_10m_max: Velocidad máxima del viento a 10 metros en km/h.
parametros_diarios = "temperature_2m_max,temperature_2m_min,precipitation_sum,wind_speed_10m_max"

# 2. Construir la URL para la API de datos históricos
# ¡OJO! La URL es diferente a la de pronóstico: usa "archive-api.open-meteo.com"
url = (
    f"https://archive-api.open-meteo.com/v1/archive?"
    f"latitude={latitud}&longitude={longitud}"
    f"&start_date={fecha_inicio}&end_date={fecha_fin}"
    f"&daily={parametros_diarios}"
    f"&timezone=Europe/Madrid"  # Especificar la zona horaria es una buena práctica
)

try:
    # 3. Realizar la petición GET a la API
    respuesta = requests.get(url)
    respuesta.raise_for_status()  # Lanza un error si la petición no fue exitosa (ej. error 4xx o 5xx)

    # 4. Convertir la respuesta a formato JSON
    datos_json = respuesta.json()

    # 5. Extraer los datos diarios y guardarlos en un DataFrame de pandas
    datos_diarios = datos_json.get('daily')

    if datos_diarios:
        df_historico = pd.DataFrame(datos_diarios)

        # Convertir la columna 'time' a un formato de fecha más manejable
        df_historico['time'] = pd.to_datetime(df_historico['time'])

        # Renombrar columnas para mayor claridad
        df_historico.rename(columns={
            'time': 'Fecha',
            'temperature_2m_max': 'Temp Max (°C)',
            'temperature_2m_min': 'Temp Min (°C)',
            'precipitation_sum': 'Precipitación (mm)',
            'wind_speed_10m_max': 'Viento Max (km/h)'
        }, inplace=True)

        print(f"--- Datos meteorológicos históricos de León para 2023 ---")
        print(f"Se han obtenido {len(df_historico)} registros.")

        print("\nPrimeros 5 días del año:")
        print(df_historico.head())

        print("\nÚltimos 5 días del año:")
        print(df_historico.tail())

    else:
        print("No se encontraron datos diarios en la respuesta de la API.")

except requests.exceptions.RequestException as e:
    print(f"Error al conectar con la API: {e}")
# Out:
# --- Datos meteorológicos históricos de León para 2023 ---
# Se han obtenido 365 registros.
#
# Primeros 5 días del año:
#        Fecha  Temp Max (°C)  Temp Min (°C)  Precipitación (mm)  \
# 0 2023-01-01           12.1            7.9                16.0
# 1 2023-01-02            8.1           -0.7                 3.3
# 2 2023-01-03            6.8           -2.7                 0.0
# 3 2023-01-04            5.9           -2.1                 0.0
# 4 2023-01-05            6.2           -2.4                 0.0
#
#    Viento Max (km/h)
# 0               24.5
# 1               14.6
# 2                9.4
# 3                5.9
# 4                9.5
#
# Últimos 5 días del año:
#          Fecha  Temp Max (°C)  Temp Min (°C)  Precipitación (mm)  \
# 360 2023-12-27            1.0           -3.6                 0.0
# 361 2023-12-28            4.3           -0.1                 4.9
# 362 2023-12-29            7.6            3.5                 1.3
# ...

# %% [markdown]
# En IA, este flujo es típico para alimentar **modelos predictivos en tiempo real**.
#
# ---
#
# ##  En resumen
#
# | Comando                        | Descripción                                              |
# | ------------------------------ | -------------------------------------------------------- |
# | `pd.read_json('archivo.json')` | Carga un archivo JSON en un DataFrame                    |
# | `pd.DataFrame(diccionario)`    | Crea un DataFrame a partir de un diccionario Python      |
# | `.to_string()`                 | Muestra todo el contenido del DataFrame                  |
# | `.head()`                      | Muestra las primeras filas (útil para inspección rápida) |
#
# ---

# %% [markdown]
# #  **Lección: Analizando DataFrames en Pandas**
#
# ---
#
# ##  **1. Visualizar los primeros datos con `head()`**
#
# Cuando cargamos un dataset, lo primero que debemos hacer es **echar un vistazo rápido a su contenido**.
#
# Pandas nos ofrece el método `head()`, que muestra las **primeras filas** del DataFrame.

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/MainakRepositor/Datasets/refs/heads/master/Pokemon.csv"
df = pd.read_csv(url)

# Mostrar las 10 primeras filas
print(df.head(10))
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %% [markdown]
# Si no especificas un número, `head()` muestra las **primeras 5 filas** por defecto:

# %%
print(df.head())
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# ---
#
# ##  **2. Visualizar las últimas filas con `tail()`**
#
# Del mismo modo, podemos usar `tail()` para ver las **últimas filas** del DataFrame.

# %%
print(df.tail())
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %% [markdown]
# Esto es muy útil para comprobar si el archivo se ha cargado correctamente o si hay valores anómalos al final.

# %% [markdown]
# ##  **3. Obtener información general con `info()`**
#
# El método `info()` muestra una **descripción técnica del DataFrame**, incluyendo:
#
# * Número de filas y columnas
# * Nombre y tipo de cada columna
# * Cuántos valores **no nulos (non-null)** hay
# * Tipo de datos (`int64`, `float64`, `object`, etc.)
# * Memoria usada

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB
# None

# %% [markdown]
# ## 🔍 **4. Interpretar el resultado**
#
# El comando `info()` te dice:
#
# | Elemento           | Significado                                 |
# | ------------------ | ------------------------------------------- |
# | **RangeIndex**     | Cuántas filas tiene el DataFrame            |
# | **Non-Null Count** | Cuántos valores válidos hay en cada columna |
# | **Dtype**          | Tipo de dato (entero, texto, decimal, etc.) |
# | **Memory usage**   | Cuánta memoria ocupa en RAM                 |
#
# 💡 En el ejemplo del dataset Pokémon, la columna **"Type 2"** tiene solo **414 valores no nulos**, lo que indica que muchos Pokémon **solo tienen un tipo**.
#
# ---
#
# ## ⚠️ **5. Detección de valores nulos**
#
# El número de **valores no nulos** (Non-Null Count) nos permite detectar **valores vacíos o faltantes**, también llamados *null* o *NaN*.

# %%
print(df.isna().sum())
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %% [markdown]
# Aquí se observa que `Type 2` tiene **386 valores nulos**, lo que concuerda con el `info()` anterior.
#
# Estos valores ausentes deben **limpiarse o tratarse** antes de aplicar modelos de IA, porque pueden afectar al rendimiento del algoritmo.
#
# (En próximas lecciones veremos cómo limpiar datos con `dropna()` y `fillna()`).

# %% [markdown]
# ---
#
# ##  **Reflexión**
#
# 1. ¿Por qué crees que es importante inspeccionar el dataset antes de analizarlo o entrenar un modelo?
# 2. ¿Qué podrías deducir si una columna tiene muchos valores nulos?
# 3. ¿Qué tipo de columna (numérica o categórica) te parece más útil para modelos de aprendizaje automático?
#
# ---
#
# ##  **Resumen**
#
# | Método         | Descripción                                  | Ejemplo           |
# | -------------- | -------------------------------------------- | ----------------- |
# | `head(n)`      | Muestra las primeras *n* filas               | `df.head(10)`     |
# | `tail(n)`      | Muestra las últimas *n* filas                | `df.tail(5)`      |
# | `info()`       | Da información técnica sobre el DataFrame    | `df.info()`       |
# | `isna().sum()` | Cuenta cuántos valores nulos hay por columna | `df.isna().sum()` |
#
# ---

# %% [markdown]
# # **Actividad práctica: Analizando datos globales en JSON**
#
# 🎯 **Objetivo:**
#
# Aprender a **leer datos reales desde una API en formato JSON**, explorar su estructura con Pandas y realizar análisis básicos sobre incendios forestales en Castilla y León.
#
# ## 📂 **Dataset oficial**
#
# 📎 Fuente:
# [Datos Abiertos de Castilla y León – Incendios forestales (API JSON)](https://analisis.datosabiertos.jcyl.es/api/explore/v2.1/catalog/datasets/incendios-forestales/exports/json?lang=es&timezone=Europe%2FMadrid)
#
# Este dataset contiene información sobre:
#
# * Fecha del incendio.
# * Provincia y municipio.
# * Causa probable.
# * Superficie afectada.
# * Medio de detección y agente de extinción.
#
# ---
#
# ##  **Pasos guiados**
#
# ### 🔹 Paso 1. Cargar los datos desde la API

# %%
df = pd.read_json("https://datosabiertos.jcyl.es/web/jcyl/risp/es/educacion/oferta-formacion-profesional/1285065645144.json")

# %% [markdown]
# ### 🔹 Paso 2. Creamos un nuevo DataFrame solo con los datos de la columna ``['fields']`` con ``json_normalize``

# %%
df_fields = pd.json_normalize(df['fields'])

# %% [markdown]
# ### 🔹 Paso 3. Aplanamos ahora la columna geomerty en otro dataframe

# %%
df_geometry = pd.json_normalize(df['geometry'])

# %% [markdown]
# ### 🔹 Paso 4. Ahora unimos con ``concat`` el DataFrame original (sin las columnas anidadas usando ``drop`` en el eje 1) con los nuevos DataFrames aplanados también en el eje 1 .

# %%
df_plano = pd.concat([
    df.drop(['geometry', 'fields'], axis=1),
    df_fields,
    df_geometry
], axis=1)

# %% [markdown]
# ---
#
# ### 🔹 Paso 5. Analizar el DataFrame
#
# * Ver las columnas disponibles
# * Visualizar los primeros datos
# * Obtener la información general

# %%
print(df_plano.columns)
print(df_plano.head())
print(df_plano.info())
print(df_plano['coordinates'])
# Out:
# Index(['datasetid', 'recordid', 'record_timestamp', 'codigo_centro',
#        'grupos_1o', 'localidad', 'ciclo_formativo_curso_de_especializacion',
#        'centro_educativo', 'familia_profesional', 'direccion_centro',
#        'codigo_familia', 'modalidad', 'provincia', 'tipo_ensenanza', 'e_mail',
#        'telefono', 'codigo_postal', 'clave_ciclo', 'grupos_2o', 'web',
#        'titularidad_centro', 'nivel_educativo', 'localizacion', 'grupos_3o',
#        'type', 'coordinates'],
#       dtype='object')
#                          datasetid                                  recordid  \
# 0  oferta-de-formacion-profesional  2adeaeb9c4b33b71115ba49e525319626ce4dfbf
# 1  oferta-de-formacion-profesional  b661f37602132682fc38df1735127315217aac66
# 2  oferta-de-formacion-profesional  363a1847951b3e055f502fab706bd6f8130a1a5d
# 3  oferta-de-formacion-profesional  e9a64ccdbcde0afdd7ee4fe8aa9b5f71cdf97837
# 4  oferta-de-formacion-profesional  acdd43dda5484414c8caf6e2a55c7af6a55cdde6
#
# ...

# %% [markdown]
# Algunos nombres típicos que aparecerán:
# `datasetid`, `recordid`, `record_timestamp`, `codigo_centro`, `grupos_1o`, `localidad`, `ciclo_formativo_curso_de_especializacion`, etc.

# %%
df_plano['record_timestamp'] = pd.to_datetime(df_plano['record_timestamp'])
df_plano['grupos_1o'] = pd.to_numeric(df_plano['grupos_1o'], errors='coerce')
df_plano['grupos_2o'] = pd.to_numeric(df_plano['grupos_2o'], errors='coerce')
df_plano['codigo_postal'] = df_plano['codigo_postal'].astype(str)

columnas_a_eliminar = ['datasetid', 'recordid', 'localizacion', 'coordinates', 'type']

df_plano = df_plano.drop(columns=columnas_a_eliminar, errors='ignore')
print(df_plano)
# Out:
#                      record_timestamp codigo_centro  grupos_1o  \
# 0    2025-02-11 13:24:45.694000+01:00      34003245        1.0
# 1    2025-02-11 13:24:45.694000+01:00      37013626        1.0
# 2    2025-02-11 13:24:45.694000+01:00      37013997        1.0
# 3    2025-02-11 13:24:45.694000+01:00      37005526        1.0
# 4    2025-02-11 13:24:45.694000+01:00      37013341        1.0
# ...                               ...           ...        ...
# 1289 2025-02-11 13:24:45.694000+01:00      24016584        1.0
# 1290 2025-02-11 13:24:45.694000+01:00      24016584        1.0
# 1291 2025-02-11 13:24:45.694000+01:00      24009622        1.0
# 1292 2025-02-11 13:24:45.694000+01:00      24006074        1.0
# 1293 2025-02-11 13:24:45.694000+01:00      24022250        1.0
#
#                    localidad  \
# 0     Villamuriel de Cerrato
# 1                      Béjar
# 2             Ciudad Rodrigo
# 3                  Salamanca
# 4                  Salamanca
# ...

# %% [markdown]
# ---
#
# #  **Lección: Limpieza de Datos con Pandas (Cleaning Data)**
#
# ---
#
# ##  **1. Qué es la limpieza de datos**
#
# La **limpieza de datos** (data cleaning) es el proceso de **detectar y corregir errores** en un conjunto de datos antes de analizarlo o entrenar un modelo de Inteligencia Artificial.
#
# Los errores más comunes en datasets reales son:
#
# | Tipo de error                   | Ejemplo                     | Solución común             |
# | ------------------------------- | --------------------------- | -------------------------- |
# | **Celdas vacías (NaN)**         | Faltan valores en columnas  | Eliminar o rellenar        |
# | **Formato incorrecto**          | Fechas como texto           | Convertir al tipo correcto |
# | **Datos erróneos o imposibles** | Edad = -5, o duración = 450 | Reemplazar o descartar     |
# | **Duplicados**                  | Registros repetidos         | Eliminar duplicados        |
#
# ---
#
# ##  **2. Dataset de ejemplo**
#
# Vamos a usar un pequeño dataset que simula datos de entrenamientos de IA:

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/carlostessier/DataSets/refs/heads/main/csv/data.csv'
df = pd.read_csv(url)

df = pd.DataFrame(data_csv)
print(df.head(10))
# Out:
#    Duration        Date  Pulse  Maxpulse  Calories
# 0        60  2020/12/01    110       130     409.1
# 1        60  2020/12/02    117       145     479.0
# 2        60  2020/12/03    103       135     340.0
# 3        45  2020/12/04    109       175     282.4
# 4        45  2020/12/05    117       148     406.0
# 5        60  2020/12/06    102       127     300.0
# 6        60  2020/12/07    110       136     374.0
# 7       450  2020/12/08    104       134     253.3
# 8        30  2020/12/09    109       133     195.1
# 9        60  2020/12/10     98       124     269.0

# %% [markdown]
# 📌 Observa que:
#
# * Hay valores **vacíos** (`None`) en `"Date"` y `"Calories"`.
# * `"Duration"` tiene un valor sospechoso: `450` (fila 7).
# * La fecha `"2020/12/26"` está en formato diferente (sin comillas, tipo texto plano).
# * Las filas 11 y 12 son **duplicadas**.
#
# ---

# %% [markdown]
# #  **Lección: Limpieza de celdas vacías con Pandas**
#
# ---
#
# ##  **1. Por qué son un problema las celdas vacías**
#
# Las **celdas vacías (NaN)** pueden provocar errores o resultados incorrectos cuando analizamos datos o entrenamos modelos de IA.
#
# Ejemplo de problemas comunes:
#
# * Un cálculo de media puede fallar o devolver un resultado incorrecto.
# * Un modelo puede interpretar los vacíos como “0” y sesgar el aprendizaje.
# * Gráficos o estadísticas pueden excluir datos sin avisar.
#
# Por eso, **limpiar o rellenar valores vacíos** es una parte esencial del *data cleaning*.
#
# ---
#
# ##  **2. Comprobamos si el dataset tiene valores vacíos**

# %%
print(df.isna().sum())
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %% [markdown]
# ##  **3. Eliminar filas con valores vacíos**
#
# Una forma de limpiar datos es **eliminar directamente** las filas que contienen valores nulos.

# %%
# Crear un nuevo DataFrame sin valores vacíos
df_sin_vacios = df.dropna()
print(df_sin_vacios.to_string())
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %% [markdown]
# **Por defecto**, `dropna()` crea un **nuevo DataFrame** y **no modifica el original**.
#
# Si quieres modificar directamente el DataFrame existente:

# %%
df.dropna(inplace=True)
print(df.head())
# Out:
#    Duration        Date  Pulse  Maxpulse  Calories
# 0        60  2020/12/01    110       130     409.1
# 1        60  2020/12/02    117       145     479.0
# 2        60  2020/12/03    103       135     340.0
# 3        45  2020/12/04    109       175     282.4
# 4        45  2020/12/05    117       148     406.0

# %% [markdown]
#  **Consejo:** Esta opción es válida si el dataset es grande y perder unas pocas filas no afecta al análisis.

# %% [markdown]
# ---
#
# #  **Lección: Limpieza de datos con formato incorrecto en Pandas**
#
# ---
#
# ##  **1. ¿Qué significa “formato incorrecto”?**
#
# En un dataset real, es frecuente encontrar **columnas con tipos de datos mezclados o mal escritos**.
#
# 🔹 Ejemplo:
#
# * Fechas escritas como texto (`'2020/12/01'`) o como número (`20201201`).
# * Valores numéricos almacenados como cadenas (`"45"` en lugar de `45`).
# * Números con comillas o caracteres no válidos.
#
# 💡 Estos errores hacen **imposible calcular medias, ordenar fechas o entrenar modelos** correctamente.
# Por eso, debemos **detectar y corregir formatos antes del análisis.**
#
# ---
#
# ##  **2. Dataset de ejemplo**
#
# Usaremos el mismo dataset de entrenamientos, que contiene errores en la columna `Date`:

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/carlostessier/DataSets/refs/heads/main/csv/data.csv'
df = pd.read_csv(url)

df = pd.DataFrame(data)

print(df.to_string())
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %% [markdown]
# 📌 Observa que:
#
# * En la fila 22 la fecha está vacía.
# * En la fila 26 (`20201226`) el formato no es válido como fecha.
# * Queremos que **todas las fechas sean objetos de tipo `datetime64`**.
#
# ---
#
# ##  **5. Reemplazar solo en una columna específica**
#
# Si solo quieres modificar una columna (por ejemplo `"Calories"`):

# %%
df.fillna({"Calories": 130}, inplace=True)
print(df.to_string())
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %% [markdown]
# Así mantienes intactas las demás columnas.
#
# ---
#
# ##  **6. Reemplazar usando medidas estadísticas**
#
# Una práctica habitual en análisis de datos y *Machine Learning* es sustituir valores vacíos por una **medida representativa** de la columna (media, mediana o moda).
#
# ---
#
# ### 🔹 a) Reemplazar por la **media**

# %%
url = 'https://raw.githubusercontent.com/carlostessier/DataSets/refs/heads/main/csv/data.csv'
df = pd.read_csv(url)

x = df["Calories"].mean()
df.fillna({"Calories": x}, inplace=True)

print(df.to_string())
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130    409.10
# 1         60  2020/12/02    117       145    479.00
# 2         60  2020/12/03    103       135    340.00
# 3         45  2020/12/04    109       175    282.40
# 4         45  2020/12/05    117       148    406.00
# 5         60  2020/12/06    102       127    300.00
# 6         60  2020/12/07    110       136    374.00
# 7        450  2020/12/08    104       134    253.30
# 8         30  2020/12/09    109       133    195.10
# 9         60  2020/12/10     98       124    269.00
# 10        60  2020/12/11    103       147    329.30
# 11        60  2020/12/12    100       120    250.70
# 12        60  2020/12/12    100       120    250.70
# 13        60  2020/12/13    106       128    345.30
# 14        60  2020/12/14    104       132    379.30
# 15        60  2020/12/15     98       123    275.00
# 16        60  2020/12/16     98       120    215.20
# ...

# %% [markdown]
# La **media (mean)** es el valor promedio:
# $$
# \text{media} = \frac{\text{suma de valores}}{\text{número de valores}}
# $$
#
#
# ---
#
# ### 🔹 b) Reemplazar por la **mediana**

# %%
url = 'https://raw.githubusercontent.com/carlostessier/DataSets/refs/heads/main/csv/data.csv'
df = pd.read_csv(url)

x = df["Calories"].median()
df.fillna({"Calories": x}, inplace=True)

print(df.to_string())
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %% [markdown]
# La **mediana (median)** es el valor que queda **en medio** al ordenar los datos.
#
# ---
#
# ### 🔹 c) Reemplazar por la **moda**

# %%
url = 'https://raw.githubusercontent.com/carlostessier/DataSets/refs/heads/main/csv/data.csv'
df = pd.read_csv(url)

x = df["Calories"].mode()[0]
df.fillna({"Calories": x}, inplace=True)

print(df.to_string())
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %% [markdown]
# La **moda (mode)** es el valor que **más se repite**.
#
# ---
#
# ## 💬 **7. ¿Qué método elegir?**
#
# | Método        | Cuándo usarlo                                          | Ventajas                        |
# | ------------- | ------------------------------------------------------ | ------------------------------- |
# | `dropna()`    | Cuando hay pocos valores vacíos y el dataset es grande | Rápido y simple                 |
# | `fillna(130)` | Cuando hay un valor fijo lógico o por defecto          | Control total del reemplazo     |
# | `mean()`      | Datos numéricos con distribución normal                | Promedia sin sesgo              |
# | `median()`    | Datos con valores atípicos (outliers)                  | Evita distorsión                |
# | `mode()`      | Datos categóricos o repetitivos                        | Preserva la categoría más común |
#
# ---

# %% [markdown]
# #  **Lección: Limpieza de datos con formato incorrecto en Pandas**
#
# ---
#
# ##  **1. ¿Qué significa “formato incorrecto”?**
#
# En un dataset real, es frecuente encontrar **columnas con tipos de datos mezclados o mal escritos**.
#
# 🔹 Ejemplo:
#
# * Fechas escritas como texto (`'2020/12/01'`) o como número (`20201201`).
# * Valores numéricos almacenados como cadenas (`"45"` en lugar de `45`).
# * Números con comillas o caracteres no válidos.
#
# 💡 Estos errores hacen **imposible calcular medias, ordenar fechas o entrenar modelos** correctamente.
# Por eso, debemos **detectar y corregir formatos antes del análisis.**
#
# ---
#
# ## 📊 **2. Dataset de ejemplo**
#
# Usaremos el mismo dataset de entrenamientos, que contiene errores en la columna `Date`:

# %%
url = 'https://raw.githubusercontent.com/carlostessier/DataSets/refs/heads/main/csv/data.csv'
df = pd.read_csv(url)

print(df.to_string())
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %% [markdown]
# 📌 Observa que:
#
# * En la fila 22 la fecha está vacía.
# * En la fila 26 (`20201226`) el formato no es válido como fecha.
# * Queremos que **todas las fechas sean objetos de tipo `datetime64`**.
#
# ---
#
# ##  **3. Convertir los datos a formato correcto**
#
# Pandas tiene una función muy útil:
#
# ###  `pd.to_datetime()`
#
# Convierte automáticamente una columna a tipo **fecha**, aunque tenga formatos diferentes.

# %%
df["Date"] = pd.to_datetime(df["Date"], format="mixed", errors="coerce")
print(df.to_string())
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %% [markdown]
# 💡 **Interpretación:**
#
# * La fecha errónea `"20201226"` se corrigió automáticamente ✅
# * La celda vacía (`None`) se convirtió en `NaT` (*Not a Time*), equivalente a `NaN` para fechas ⚠️
#
# ---
#
# ## 🧹 **4. Eliminar filas con fechas inválidas**
#
# Podemos tratar las fechas `NaT` como valores nulos y eliminarlas:

# %%
df.dropna(subset=["Date"], inplace=True)

print(df.to_string())
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %% [markdown]
# Esto elimina las filas que **no tienen una fecha válida**. En nuestro caso la 22.
#
#
# ## **5. Verificar el resultado**

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  31 non-null     int64
#  1   Date      31 non-null     datetime64[ns]
#  2   Pulse     31 non-null     int64
#  3   Maxpulse  31 non-null     int64
#  4   Calories  29 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(3)
# memory usage: 1.5 KB
# None

# %% [markdown]
# ✅ Ahora la columna **`Date`** tiene un tipo correcto (`datetime64`), y podemos ordenarla o usarla en gráficos temporales.

# %% [markdown]
# ---
#
# ##  **6. Otras conversiones útiles**
#
# | Tipo de dato      | Método                | Ejemplo                                                           |
# | ----------------- | --------------------- | ----------------------------------------------------------------- |
# | Texto a número    | `pd.to_numeric()`     | `df["Calories"] = pd.to_numeric(df["Calories"], errors="coerce")` |
# | Texto a fecha     | `pd.to_datetime()`    | `df["Date"] = pd.to_datetime(df["Date"], errors="coerce")`        |
# | Texto a categoría | `.astype("category")` | `df["Type"] = df["Type"].astype("category")`                      |
#
# ---
#
# ## 💬 **Reflexión**
#
# 1. ¿Qué problemas podría generar un tipo de dato incorrecto al entrenar un modelo de IA?
# 2. ¿Qué significa el valor `NaT` en Pandas?
# 3. ¿Qué diferencias hay entre usar `errors="coerce"` y eliminar directamente las filas?
#
# ---
#
# ## ✅ **Resumen**
#
# | Tarea                     | Método                    | Descripción                       |
# | ------------------------- | ------------------------- | --------------------------------- |
# | Convertir a fecha         | `pd.to_datetime()`        | Convierte textos a fechas         |
# | Manejar errores           | `errors="coerce"`         | Cambia formatos inválidos a `NaT` |
# | Eliminar fechas inválidas | `dropna(subset=["Date"])` | Borra filas sin fecha             |
# | Verificar formato         | `df.info()`               | Comprueba tipo de datos           |
#
# ---

# %% [markdown]
# #  **Lección: Corrigiendo datos erróneos en Pandas**
#
# ---
#
# ##  **1. ¿Qué son los “datos erróneos”?**
#
# Los **datos erróneos** no siempre están vacíos o mal formateados.
# Pueden ser valores **que no tienen sentido lógico o estadístico** dentro del contexto del dataset.
#
# 🔹 Ejemplo clásico:
# En un registro de entrenamientos, la **duración media** suele ser entre 30 y 60 minutos.
# Si aparece un valor de **450 minutos**, es probable que sea un **error humano** (un “0” extra).
#
# ---
#
# ##  **2. Dataset de ejemplo**

# %%
url = 'https://raw.githubusercontent.com/carlostessier/DataSets/refs/heads/main/csv/data.csv'
df = pd.read_csv(url)

print(df.to_string())
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %% [markdown]
# 💡 Todo parece correcto en la característica *Duration* salvo la duración: 450 minutos (7,5 horas) no tiene sentido.
#
# ---
#
# ## 🧩 **3. Sustituir un valor erróneo (método directo)**
#
# Podemos **corregir manualmente** un valor aislado con `.loc[]`:

# %%
df.loc[7, "Duration"] = 45

print(df.head(10))
# Out:
#    Duration        Date  Pulse  Maxpulse  Calories
# 0        60  2020/12/01    110       130     409.1
# 1        60  2020/12/02    117       145     479.0
# 2        60  2020/12/03    103       135     340.0
# 3        45  2020/12/04    109       175     282.4
# 4        45  2020/12/05    117       148     406.0
# 5        60  2020/12/06    102       127     300.0
# 6        60  2020/12/07    110       136     374.0
# 7        45  2020/12/08    104       134     253.3
# 8        30  2020/12/09    109       133     195.1
# 9        60  2020/12/10     98       124     269.0

# %% [markdown]
# ✅ Esto reemplaza el valor erróneo por **45** en la fila 7.
#
# 📌 Útil cuando el dataset es pequeño o los errores son muy concretos.
#
# ---
#
# ##  **4. Crear reglas automáticas para detectar y corregir**
#
# En datasets grandes no podemos corregir valor a valor.
# Podemos definir **límites válidos (umbrales)** y aplicar reglas automáticas.
#
# Por ejemplo, si todas las duraciones deben estar entre 30 y 120 minutos:

# %%
url = 'https://raw.githubusercontent.com/carlostessier/DataSets/refs/heads/main/csv/data.csv'
df = pd.read_csv(url)

for x in df.index:
    if df.loc[x, "Duration"] > 120:
        df.loc[x, "Duration"] = 120

print(df.head(10))
# Out:
#    Duration        Date  Pulse  Maxpulse  Calories
# 0        60  2020/12/01    110       130     409.1
# 1        60  2020/12/02    117       145     479.0
# 2        60  2020/12/03    103       135     340.0
# 3        45  2020/12/04    109       175     282.4
# 4        45  2020/12/05    117       148     406.0
# 5        60  2020/12/06    102       127     300.0
# 6        60  2020/12/07    110       136     374.0
# 7       120  2020/12/08    104       134     253.3
# 8        30  2020/12/09    109       133     195.1
# 9        60  2020/12/10     98       124     269.0

# %% [markdown]
# 💡 `.loc[]` actúa como una lupa sobre el DataFrame y permite modificar datos directamente.
#
# ---
#
# ## 🔁 **5. Alternativa más “pandasiana” (sin bucles)**
#
# Pandas permite hacerlo sin necesidad de recorrer fila a fila:

# %%
url = 'https://raw.githubusercontent.com/carlostessier/DataSets/refs/heads/main/csv/data.csv'
df = pd.read_csv(url)

df.loc[df["Duration"] > 120, "Duration"] = 120


print(df.head(10))
# Out:
#    Duration        Date  Pulse  Maxpulse  Calories
# 0        60  2020/12/01    110       130     409.1
# 1        60  2020/12/02    117       145     479.0
# 2        60  2020/12/03    103       135     340.0
# 3        45  2020/12/04    109       175     282.4
# 4        45  2020/12/05    117       148     406.0
# 5        60  2020/12/06    102       127     300.0
# 6        60  2020/12/07    110       136     374.0
# 7       120  2020/12/08    104       134     253.3
# 8        30  2020/12/09    109       133     195.1
# 9        60  2020/12/10     98       124     269.0

# %% [markdown]
# ✅ Mismo resultado, pero más rápido y legible.
#
# ---
#
# ##  **6. Eliminar filas con valores erróneos**
#
# En algunos casos no conviene reemplazar, sino **eliminar completamente** los registros que rompen la coherencia.

# %%
url = 'https://raw.githubusercontent.com/carlostessier/DataSets/refs/heads/main/csv/data.csv'
df = pd.read_csv(url)

df = df.drop(df[df["Duration"] > 120].index)

print(df.head(10))
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3

# %% [markdown]
# 💡 Esta opción se usa cuando:
#
# * No sabemos cuál sería el valor correcto.
# * Los datos erróneos son pocos y no afectan el análisis.
#
# ---
#
# ##  **7. Comprobar la corrección**

# %%
print(df["Duration"].describe())
# Out:
# count    31.000000
# mean     56.129032
# std       7.714670
# min      30.000000
# 25%      60.000000
# 50%      60.000000
# 75%      60.000000
# max      60.000000
# Name: Duration, dtype: float64

# %% [markdown]
#  Ya no hay valores anómalos por encima de 120.
#
# ---
#
# ## 💬 **Reflexión**
#
# 1. ¿Por qué a veces es mejor corregir un valor y otras veces eliminarlo?
# 2. ¿Qué consecuencias tendría mantener datos erróneos en un modelo de predicción?
# 3. ¿Cómo podrías aplicar reglas similares para detectar errores en otras columnas (por ejemplo, `Pulse` o `Calories`)?
#
# ---
#
# ## ✅ **Resumen**
#
# | Situación                | Acción                        | Ejemplo                                                 |
# | ------------------------ | ----------------------------- | ------------------------------------------------------- |
# | Error aislado y evidente | Corregir directamente         | `df.loc[7, "Duration"] = 45`                            |
# | Valores fuera de rango   | Reemplazar con límite o media | `df.loc[df["Duration"] > 120, "Duration"] = 120`        |
# | Datos sin sentido        | Eliminar fila                 | `df.drop(df[df["Duration"] > 120].index, inplace=True)` |
# | Validación general       | Revisar estadísticas          | `df.describe()`                                         |
#
# ---

# %% [markdown]
# ---
# # **Continuación actividad práctica**
#
# ### 🔹 Paso 6. Limpieza básica de datos
#
# #### 6.1 Separar las coordenadas en Latitud y Longitud

# %%
# Cambiar df_plano por el nombre de tu dataframe
# df_plano[['latitud', 'longitud']] = pd.DataFrame(df_plano['localizacion'].tolist(), index=df_plano.index)

# Hecho en otra celda
# df_plano[["lat", "lon"]] = pd.DataFrame(df_plano["coordinates"].tolist(), index=df.index)

# %% [markdown]
# #### 6.2 Arreglar formatos inadecuados
#
# *   ``[record_timestamp]`` a ``datetime`` con ``to_datetime()``
# *   ``['grupos_1o']`` y ``['grupos_2o']`` a numérico con to_numeric y la opción ``errors='coerce'``
# * Eliminar Columnas Redudante o Innecesarias creando una lista llamada columnas_a_eliminar y pasándoselas a ``drop`` con la opción ``columns`=columnas_a_eliminar`` y ``errors='ignore'`` para que no falle si alguna no existe

# %%
df_plano['record_timestamp'] = pd.to_datetime(df_plano['record_timestamp'], format="mixed", errors="coerce")

# %% [markdown]
# #### 6.3 Revisar si hay valores nulos

# %%
print(df_plano.isna().sum())
# Out:
# record_timestamp                               0
# codigo_centro                                  0
# grupos_1o                                      0
# localidad                                      0
# ciclo_formativo_curso_de_especializacion       0
# centro_educativo                               0
# familia_profesional                            0
# direccion_centro                               0
# codigo_familia                                 0
# modalidad                                      0
# provincia                                      0
# tipo_ensenanza                                 0
# e_mail                                         0
# telefono                                       0
# codigo_postal                                  0
# clave_ciclo                                    0
# grupos_2o                                      0
# web                                            0
# titularidad_centro                             0
# ...

# %% [markdown]
# #### 6.4 Rellenar los valores nulos por 0.0

# %%
df_plano.fillna({"grupos_3o": 0.0}, inplace=True);

print(df_plano.isna().sum())
# Out:
# record_timestamp                            0
# codigo_centro                               0
# grupos_1o                                   0
# localidad                                   0
# ciclo_formativo_curso_de_especializacion    0
# centro_educativo                            0
# familia_profesional                         0
# direccion_centro                            0
# codigo_familia                              0
# modalidad                                   0
# provincia                                   0
# tipo_ensenanza                              0
# e_mail                                      0
# telefono                                    0
# codigo_postal                               0
# clave_ciclo                                 0
# grupos_2o                                   0
# web                                         0
# titularidad_centro                          0
# nivel_educativo                             0
# ...

# %% [markdown]
# 6.5 Verificar si hay valores erróneos

# %%
print(df_plano) # No parece que haya
# Out:
#                      record_timestamp codigo_centro  grupos_1o  \
# 0    2025-02-11 13:24:45.694000+01:00      34003245        1.0
# 1    2025-02-11 13:24:45.694000+01:00      37013626        1.0
# 2    2025-02-11 13:24:45.694000+01:00      37013997        1.0
# 3    2025-02-11 13:24:45.694000+01:00      37005526        1.0
# 4    2025-02-11 13:24:45.694000+01:00      37013341        1.0
# ...                               ...           ...        ...
# 1289 2025-02-11 13:24:45.694000+01:00      24016584        1.0
# 1290 2025-02-11 13:24:45.694000+01:00      24016584        1.0
# 1291 2025-02-11 13:24:45.694000+01:00      24009622        1.0
# 1292 2025-02-11 13:24:45.694000+01:00      24006074        1.0
# 1293 2025-02-11 13:24:45.694000+01:00      24022250        1.0
#
#                    localidad  \
# 0     Villamuriel de Cerrato
# 1                      Béjar
# 2             Ciudad Rodrigo
# 3                  Salamanca
# 4                  Salamanca
# ...

# %% [markdown]
# 6.6 Eliminar valores duplicados si existieran

# %%
df_plano.drop_duplicates(inplace=True)

# %% [markdown]
# ### 🔹 Análisis geográfico de los Ciclos Formativos en Castilla y León
#
# #### 🔸 a) ¿Cuántos ciclos hay por provincia? (usar ``value_counts()``) Reto: Ordenarlo de mayor a menor

# %%
print(df_plano.value_counts("provincia")) # Ya sale ordenado de mayor a menor???????
# Out:
# provincia
# Valladolid    299
# León          222
# Burgos        202
# Salamanca     178
# Palencia       88
# Zamora         87
# Ávila          85
# Segovia        78
# Soria          55
# Name: count, dtype: int64

# %% [markdown]
# #### 🔸 b) Top 10 familias profesionales ofertadas (usar ``head()``)

# %%
print(df_plano.value_counts("familia_profesional").head(10))
# Out:
# familia_profesional
# Administración y Gestión                      157
# Sanidad                                       138
# Electricidad y Electrónica                    137
# Informática y Comunicaciones                  133
# Hostelería y Turismo                           91
# Transporte y Mantenimiento de Vehículos        91
# Servicios Socioculturales y a la Comunidad     86
# Comercio y Marketing                           81
# Imagen Personal                                59
# Fabricación Mecánica                           58
# Name: count, dtype: int64

# %% [markdown]
# #### 🔸 c) Modalidad (presencial/online/dual) por provincia (tabla dinámica) (usar ``crosstab`` pasándole las columnas del dataframe)

# %%
pd.crosstab(df_plano["provincia"], [df_plano["modalidad"]], rownames=["Provincia"], colnames=["Modalidad"])
# Out:
# Modalidad   Distancia  Presencial
# Provincia
# Burgos             11         191
# León               15         207
# Palencia            5          83
# Salamanca          10         168
# Segovia             3          75
# Soria               2          53
# Valladolid         36         263
# Zamora              5          82
# Ávila               2          83

# %% [markdown]
# 🔸 d) Centros con más ciclos ofertados

# %%
print(df_plano.value_counts("centro_educativo").head(10))
# Out:
# centro_educativo
# CIFP CIUDAD DE LEÓN            25
# CIFP RODRÍGUEZ FABRÉS          23
# RÍO DUERO                      22
# CIFP JUAN DE COLONIA           21
# CIFP FELIPE VI                 20
# CIFP RÍO TORMES                18
# GREGORIO FERNÁNDEZ             16
# CIFP TECNOLÓGICO INDUSTRIAL    16
# CIFP CIUDAD DE ZAMORA          16
# IES RIBERA DE CASTILLA         16
# Name: count, dtype: int64

# %% [markdown]
# 🔸 d) ¿Cómo se distribuye la oferta pública, concertada y privada en cada provincia? (Usar la función ``groupby`` y llamar después a ``.size()`` y ``.unstack(fill_value=0)``) Para darle formato de tabla

# %%
pd.crosstab(df_plano["provincia"], [df_plano["tipo_ensenanza"]], rownames=["Provincia"], colnames=["Tipo ensenyanza"]) # Estoy con el teclado ingles
# Out:
# Tipo ensenyanza  Concertada  Privada  Pública
# Provincia
# Burgos                   73        7      122
# León                     36       18      168
# Palencia                 21        0       67
# Salamanca                33       27      118
# Segovia                   0        0       78
# Soria                     2        0       53
# Valladolid               79       69      151
# Zamora                    5        1       81
# Ávila                     8        0       77

# %% [markdown]
# 🔸 f)  ¿En qué se especializa la provincia de Soria? (Familias profesionales más comunes en Soria)

# %%
filtrado = df_plano[df_plano["provincia"] == "Soria"]
print(filtrado.value_counts("familia_profesional").head(10))
# Out:
# familia_profesional
# Informática y Comunicaciones                  7
# Comercio y Marketing                          5
# Sanidad                                       5
# Hostelería y Turismo                          5
# Transporte y Mantenimiento de Vehículos       4
# Administración y Gestión                      4
# Servicios Socioculturales y a la Comunidad    3
# Instalación y Mantenimiento                   3
# Electricidad y Electrónica                    3
# Agraria                                       3
# Name: count, dtype: int64

# %% [markdown]
# 🔸 g) ¿Qué familias profesionales son predominantemente ofrecidas por centros privados?

# %%
filtrado_privada = df_plano[df_plano["tipo_ensenanza"] == "Privada"]
print(filtrado_privada.value_counts("familia_profesional").head(10))
# Out:
# familia_profesional
# Sanidad                                       48
# Servicios Socioculturales y a la Comunidad    19
# Actividades Físicas y Deportivas              11
# Informática y Comunicaciones                   9
# Comercio y Marketing                           8
# Hostelería y Turismo                           6
# Administración y Gestión                       5
# Imagen y Sonido                                5
# Imagen Personal                                3
# Edificación y Obra Civil                       3
# Name: count, dtype: int64

# %% [markdown]
# 🔸 h)  Dentro de la provincia de León, ¿qué localidades tienen oferta formativa de la familia de informática y comunicaciones?

# %%
print(df_plano[(df_plano["provincia"] == "León") & (df_plano["familia_profesional"] == "Informática y Comunicaciones")]["localidad"].unique())
# Out:
# ['Villabalter' 'Ponferrada' 'Villablino' 'La Robla' 'León' 'Fabero']

# %% [markdown]
# 🔸 i) Mostrar un gráfico con el número de ciclos por provincia de Castilla y León

# %%
import matplotlib.pyplot as plt

df_plano.value_counts("provincia").plot(kind='bar', color='skyblue', edgecolor='black')

plt.title("Oferta de FP por provincia")
plt.xlabel("Provincia")
plt.ylabel("Cantidad de cursos")
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# ¿Qué provincias concentran mayor oferta de FP? ¿Y cuáles menos?
#
# ¿Qué familias profesionales son más frecuentes? ¿Cuadra con la realidad socioeconómica de CyL?
#
# ¿Cómo varía la modalidad (presencial/online/dual) según provincia o familia?
#
# ¿Cómo podrías filtrar solo Informática y Comunicaciones y analizar su distribución?

# %% [markdown]
# Respuesta:
# 1. Las que mayor oferta tienen son la que tienen más población
# 2. Las más comunes son: administración, sanidad, electricidad y electronica, informática y comunicaciones y hostelería. Reflejan bastante bien la realidad de la oferta de empleo y demanda de las empresas en el sector
# 3. Hay más variedad online en Valladolid, la más poblada es dónde más variedad online hay. Sin embargo, en el resto de provincias no es proporcional a la población o al resto de la oferta de formación profesional. Es así porque es muy probable que en Valladolid haya mucha demanda de gente trabajadora que quiera aprender algo nuevo mientras mantiene su trabajo actual, y la mejor forma de ello son las clases en línea, ya que aportan más flexibilidad

# %%
filtrado_privada = df_plano[df_plano["familia_profesional"] == "Informática y Comunicaciones"]
print(filtrado_privada.value_counts("provincia"))
# Out:
# provincia
# Valladolid    40
# Salamanca     20
# Burgos        18
# León          16
# Ávila         11
# Zamora         8
# Segovia        7
# Soria          7
# Palencia       6
# Name: count, dtype: int64

# %% [markdown]
# 4. Es atípico con el resto de la oferta. Llama la atención que León se encuentra en el cuarto puesto muy cerca de Ávila. Es posible que sea debido a que haya mayor demanda de otros trabajos, probablemente relacionados con la sanidad debido al envejecimiento de la población en la provincia y la falta de variedad de empresas en la provincia (interpretación personal)

# %% [markdown]
# #  **Eliminación de duplicados en Pandas**
#
# ---
#
# ##  **1. Qué son los duplicados**
#
# En los datasets reales, es habitual encontrar **filas duplicadas**, es decir, **registros repetidos exactamente iguales**.
#
# Esto puede suceder cuando:
#
# * Se combinan fuentes de datos distintas.
# * Se guardan varias veces las mismas mediciones.
# * Hay errores de registro o importación.
#
# 🔹 **Ejemplo del dataset de entrenamientos**
# Observa las filas 11 y 12: son idénticas.

# %%
url = 'https://raw.githubusercontent.com/carlostessier/DataSets/refs/heads/main/csv/data.csv'
df = pd.read_csv(url)

print(df.to_string())
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %% [markdown]
# ---
#
# ##  **2. Detectar duplicados con `duplicated()`**
#
# Pandas ofrece el método `duplicated()` para detectar filas repetidas.

# %%
print(df.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %% [markdown]
# 💡 **Interpretación:**
#
# * `True` → la fila es **un duplicado**.
# * `False` → la fila es **única**.
#
# ---
#
# ##  **3. Ver solo las filas duplicadas**
#
# Para ver las filas duplicadas directamente:

# %%
print(df[df.duplicated()])
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 12        60  2020/12/12    100       120     250.7

# %% [markdown]
# ---
#
# ##  **4. Eliminar duplicados con `drop_duplicates()`**
#
# Para **eliminar filas repetidas**, usamos `drop_duplicates()`.

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# 📌 Con `inplace=True` modificamos el DataFrame original directamente.
# Sin ese argumento, el método devuelve una **copia** limpia.
#
# ---
#
# ## ⚙️ **5. Comprobación final**

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ✅ Ya no hay filas duplicadas.
#
# ---
#
# ##  **6. Eliminar duplicados según columnas específicas**
#
# A veces queremos considerar duplicado solo si coinciden ciertas columnas (por ejemplo, mismas fechas y pulsaciones):

# %%
url = 'https://raw.githubusercontent.com/carlostessier/DataSets/refs/heads/main/csv/data.csv'
df = pd.read_csv(url)

df.drop_duplicates(subset=["Date", "Pulse"], inplace=True)

print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# Así mantenemos la fila más reciente o completa, y eliminamos las redundantes.
#
# ---
#
# ## 🧠 **7. Evitar duplicados al combinar datos**
#
# Cuando unimos datasets con `concat()` o `merge()`, es buena práctica revisar después si se han duplicado registros:

# %%
df1 = pd.DataFrame({
    "Nombre": ["Ana", "Luis", "María"],
    "Edad": [23, 30, 25]
})

df2 = pd.DataFrame({
    "Nombre": ["Luis", "María", "Pedro"],
    "Edad": [30, 25, 28]
})

df = pd.concat([df1, df2])

print(df)

df.drop_duplicates(inplace=True)

print("\n Eliminamos duplicados\n")

print(df)
# Out:
#   Nombre  Edad
# 0    Ana    23
# 1   Luis    30
# 2  María    25
# 0   Luis    30
# 1  María    25
# 2  Pedro    28
#
#  Eliminamos duplicados
#
#   Nombre  Edad
# 0    Ana    23
# 1   Luis    30
# 2  María    25
# 2  Pedro    28

# %% [markdown]
# 💬 **Consejo:** Incorpora siempre un paso de verificación de duplicados en tu flujo de limpieza (*pipeline*).
#
# ---
#
# ## ✅ **Resumen**
#
# | Tarea               | Método                             | Descripción                    |
# | ------------------- | ---------------------------------- | ------------------------------ |
# | Detectar duplicados | `df.duplicated()`                  | Devuelve `True/False` por fila |
# | Mostrar duplicados  | `df[df.duplicated()]`              | Filtra las filas repetidas     |
# | Eliminar duplicados | `df.drop_duplicates(inplace=True)` | Borra las filas duplicadas     |
# | Basado en columnas  | `subset=["col1", "col2"]`          | Compara solo esas columnas     |

# %% [markdown]
# #  **Lección: Correlaciones de Datos en Pandas**
#
# ---
#
# ##  **1. ¿Qué es una correlación?**
#
# En análisis de datos e inteligencia artificial, una **correlación** mide **cómo se relacionan dos variables**:
# si aumentan o disminuyen juntas, o si no guardan relación alguna.
#
# Pandas nos permite calcular correlaciones de forma muy sencilla con el método `.corr()`.
#
# ---
#
# ##  **2. Dataset de ejemplo**
#
# Usaremos el dataset de entrenamientos `training_data.csv` con más datos:

# %%
url = 'https://raw.githubusercontent.com/carlostessier/DataSets/refs/heads/main/csv/training_data.csv'
df = pd.read_csv(url)

print(df.head())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %% [markdown]
# ---
#
# ##  **3. Calcular la correlación**
#
# Pandas tiene un método muy útil: **`df.corr()`**, que calcula automáticamente las correlaciones entre todas las columnas numéricas del DataFrame.

# %%
print(df.corr(numeric_only=True))
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.155408  0.009403  0.922721
# Pulse    -0.155408  1.000000  0.786535  0.025120
# Maxpulse  0.009403  0.786535  1.000000  0.203814
# Calories  0.922721  0.025120  0.203814  1.000000

# %% [markdown]
# ---
#
# ##  **4. Interpretación de los resultados**
#
# Cada número indica **la fuerza y dirección de la relación** entre dos variables.
# El valor varía de **-1 a 1**:
#
# | Valor           | Interpretación                | Significado                      |
# | --------------- | ----------------------------- | -------------------------------- |
# | **1.0**         | Correlación perfecta positiva | Ambas variables aumentan juntas  |
# | **0.8 a 0.6**   | Correlación fuerte            | Si una sube, la otra suele subir |
# | **0.4 a 0.2**   | Correlación débil             | Relación poco fiable             |
# | **0.0**         | Sin correlación               | No hay relación lineal           |
# | **-0.6 a -1.0** | Correlación negativa          | Cuando una sube, la otra baja    |
#
# ---
#
# ##  **5. Ejemplo visual: buena vs mala correlación**
#
# | Ejemplo                           | Descripción                                                  | Interpretación        |
# | --------------------------------- | ------------------------------------------------------------ | --------------------- |
# | 🔹 **Duration – Calories:** 0.92  | Cuanto más se entrena, más calorías se queman.               | Buena correlación ✅   |
# | 🔹 **Duration – Maxpulse:** 0.009 | No hay relación directa entre la duración y el pulso máximo. | Mala correlación ❌    |
# | 🔹 **Pulse – Maxpulse:** 0.78     | A mayor pulso medio, mayor pulso máximo.                     | Correlación fuerte 💪 |
#
# ---
#
# ##  **6. Visualización de correlaciones**
#
# Podemos mostrar la matriz de correlaciones como un **mapa de calor (heatmap)** para interpretarla fácilmente.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

corr = df.corr(numeric_only=True)

sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Matriz de correlación de variables del entrenamiento")
plt.show()

# %% [markdown]
#  Esto genera un gráfico donde los colores indican la fuerza de la relación:
#
# * 🔴 **Rojo fuerte → correlación positiva**
# * 🔵 **Azul fuerte → correlación negativa**
#
# ---
#
# ## 💬 **7. Aplicación en Inteligencia Artificial**
#
# En IA y *Machine Learning*, la correlación es fundamental porque:
#
# * Permite **detectar variables redundantes o poco relevantes**.
# * Ayuda a **reducir la dimensionalidad** del modelo (quedarse solo con las variables útiles).
# * Sirve como paso previo a técnicas como **regresión lineal o PCA (análisis de componentes principales)**.
#
# 💡 Ejemplo:
#
# > Si “Duration” y “Calories” tienen una correlación de 0.92, podrías usar una para predecir la otra con un modelo de regresión.
#
# ---
#
# ## 🧠 **8. Resumen**
#
# | Concepto               | Método                 | Descripción                                |
# | ---------------------- | ---------------------- | ------------------------------------------ |
# | Calcular correlación   | `df.corr()`            | Mide relación entre columnas numéricas     |
# | Visualizar correlación | `sns.heatmap()`        | Representa gráficamente la matriz          |
# | Interpretar valores    | De -1 a 1              | +1 fuerte positiva / -1 fuerte negativa    |
# | Aplicación IA          | Selección de variables | Identificar relaciones útiles para modelos |
